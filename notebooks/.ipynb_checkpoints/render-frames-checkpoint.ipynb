# %% [markdown]
# This notebook contains code for rendering .png images according to a predefined fsleyes orthographic view, of 3D-FLAIR based MNI normalized nrCBV maps overlayed on a MNI brain regions template. It also uses ffmpeg to make videos of the images.

# %% [markdown]
# 1. Specify epi_corrections output directory

# %%
output_directory_suffix = "2019_04_25"
# On local file system:
#corrections_base_directory = "../../epi_corrections_out_" + output_directory_suffix
# On samba share (remote file sytem):
corrections_base_directory = "/run/user/1000/gvfs/smb-share:server=192.168.1.207,share=hdd3tb1/data/IVS_EPI_BASELINE/epi_corrections_out_" + output_directory_suffix
corrections_base_directory
# Out:
# '/run/user/1000/gvfs/smb-share:server=192.168.1.207,share=hdd3tb1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_04_25'

# %% [markdown]
# 2. Since nICE introduced files with spaces in their file names,
# recursively replace spaces in folders and file names.
# The fsleyes rendering bash command did not accept
# spaces in file names and directories.

# %%
from utils import replace_spaces_with_underscore
#replace_spaces_with_underscore(corrections_base_directory + "/EPI_raw_DSC")
#replace_spaces_with_underscore(corrections_base_directory + "/EPI_applytopup")
#replace_spaces_with_underscore(corrections_base_directory + "/EPI_applyepic")

# %% [markdown]
# 3. Find the MNI-normalized, NordicICE intensity Normalized Relative CBV files. Can be done remotely.

# %%
from search import find_cbv_files

[raw_cbv_files_e1, \
 topup_cbv_files_e1, \
 epic_cbv_files_e1, \
 raw_cbv_files_e2, \
 topup_cbv_files_e2, \
 epic_cbv_files_e2] = find_cbv_files(corrections_base_directory)

# %%
# A check
print("Equal number of detected CBV files for raw (uncorrected), topup, and epic correction methods: %r" % \
      (len(raw_cbv_files_e1) == \
       len(raw_cbv_files_e2) == \
       len(topup_cbv_files_e1) == \
       len(topup_cbv_files_e2) == \
       len(epic_cbv_files_e1) == \
       len(epic_cbv_files_e2)))
print("Number of subject CBVs: %i" % len(raw_cbv_files_e1))
# Out:
# Equal number of detected CBV files for raw (uncorrected), topup, and epic correction methods: True
# Number of subject CBVs: 45

# %% [markdown]
# 4. Find the corresponding MNI label files
# (should perhaps be identical to each other, but just to make sure..)

# %%
from search import find_label_files

[raw_label_files_e1, \
 topup_label_files_e1, \
 epic_label_files_e1, \
 raw_label_files_e2, \
 topup_label_files_e2, \
 epic_label_files_e2] = find_label_files(corrections_base_directory)

# %%
# A check
print("Equal number of detected label files for raw (uncorrected), topup, and epic correction methods: %r" % \
      (len(raw_label_files_e1) == \
       len(raw_label_files_e2) == \
       len(topup_label_files_e1) == \
       len(topup_label_files_e2) == \
       len(epic_label_files_e1) == \
       len(epic_label_files_e2)))
print("Number of subject label files: %i" % len(raw_label_files_e1))
# Out:
# Equal number of detected label files for raw (uncorrected), topup, and epic correction methods: True
# Number of subject label files: 45

# %% [markdown]
# 5. For the raw, topup and epic Gradient Echo (GE) and Spin Echo (SE) nrCBV data + MNI regions file, render .png images in a predefined orthographic view, then make a video. __Note:__ The following cells must run within a fsl X environment

# %%
# %%bash -s "{" ".join(raw_cbv_files_e1)}" "{" ".join(topup_cbv_files_e1)}" "{" ".join(epic_cbv_files_e1)}" "{" ".join(raw_cbv_files_e2)}" "{" ".join(topup_cbv_files_e2)}" "{" ".join(epic_cbv_files_e2)}" "{" ".join(raw_label_files_e1)}" "{" ".join(topup_label_files_e1)}" "{" ".join(epic_label_files_e1)}" "{" ".join(raw_label_files_e2)}" "{" ".join(topup_label_files_e2)}" "{" ".join(epic_label_files_e2)}"
# IFS=' ' read -r -a raw_cbv_files_e1 <<< "$1"
# IFS=' ' read -r -a topup_cbv_files_e1 <<< "$2"
# IFS=' ' read -r -a epic_cbv_files_e1 <<< "$3"
# IFS=' ' read -r -a raw_cbv_files_e2 <<< "$4"
# IFS=' ' read -r -a topup_cbv_files_e2 <<< "$5"
# IFS=' ' read -r -a epic_cbv_files_e2 <<< "$6"
# IFS=' ' read -r -a raw_label_files_e1 <<< "$7"
# IFS=' ' read -r -a topup_label_files_e1 <<< "$8"
# IFS=' ' read -r -a epic_label_files_e1 <<< "$9"
# IFS=' ' read -r -a raw_label_files_e2 <<< "${10}"
# IFS=' ' read -r -a topup_label_files_e2 <<< "${11}"
# IFS=' ' read -r -a epic_label_files_e2 <<< "${12}"
# render() {
#     local -n _cbv_files=$1
#     local -n _label_files=$2
#     local -n _render_dir=$3
#
#     # Remove existing render directory.
#     if [ -d "$_render_dir" ]; then rm -rd "$_render_dir"; fi
#
#     mkdir -p "$_render_dir"
#
#     for index in "${!_cbv_files[@]}"
#     do
#         cbv_file="${_cbv_files[index]}"
#         label_file="${_label_files[index]}"
#
#         cbv_file_name="$(basename $cbv_file)"
#         label_file_name="$(basename $label_file)"
#
#         render_command='fsleyes
#             render
#             --outfile "'$_render_dir'/'output_$(printf "%03d\n" $index)'"
#             --scene ortho
#             --worldLoc 9.918212890625e-05 -18.000099182128906 7.999900817871094
#             --displaySpace
#             '$cbv_file'
#             --xcentre -0.00000 -0.11019
#             --ycentre -0.00000 -0.11019
#             --zcentre -0.00000 -0.00000
#             --xzoom 803.0573770888577
#             --yzoom 809.4712464952298
#             --zzoom 803.057377088858
#             --hideLabels
#             --labelSize 14
#             --layout horizontal
#             --hideCursor
#             --bgColour 0.0 0.0 0.0
#             --fgColour 1.0 1.0 1.0
#             --cursorColour 0.0 1.0 0.0
#             --colourBarLocation top
#             --colourBarLabelSide top-left
#             --performance 3
#             '$cbv_file'
#             --name '$cbv_file_name'
#             --overlayType volume
#             --alpha 100.0
#             --brightness 64.94720130619707
#             --contrast 79.89440261239416
#             --cmap hot
#             --negativeCmap greyscale
#             --displayRange 0.0 12.0
#             --clippingRange 0.0 30.140860195159913
#             --gamma 0.0
#             --cmapResolution 256
#             --interpolation none
#             --numSteps 100
#             --blendFactor 0.1
#             --smoothing 0
#             --resolution 100
#             --numInnerSteps 10
#             --clipMode intersection
#             --volume 0
#             '$label_file'
#             --name '$label_file_name'
#             --overlayType volume
#             --alpha 37.33333333798995
#             --brightness 50.0
#             --contrast 50.0
#             --cmap greyscale
#             --negativeCmap greyscale
#             --displayRange 0.0 207.0
#             --clippingRange 0.0 209.07
#             --gamma 0.0
#             --cmapResolution 256
#             --interpolation none
#             --numSteps 100
#             --blendFactor 0.1
#             --smoothing 0
#             --resolution 100
#             --numInnerSteps 10
#             --clipMode intersection
#             --volume 0'
#         echo $render_command >> "$_render_dir/commands.txt"
#         #echo $render_command
#         eval $render_command
#         echo "--Finished rendering volume $index to .png--"
#     done
#     ffmpeg -framerate 1 -i "$_render_dir"/output_%03d.png -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -c:v libx264 -preset slow -profile:v high -level:v 4.0 -pix_fmt yuv420p -crf 1 "$_render_dir"/video.mp4
#     echo "--Finished rendering pngs to video--"
# }
# render_dir_raw_e1="/home/ivar/Desktop/temp/render/EPI_raw_DSC/e1"
# render raw_cbv_files_e1 raw_label_files_e1 render_dir_raw_e1
# sleep 1 # Sleep 1 second; this was necessary otherwise the next call of render() function did seem to get emtpy render dir argument...
# render_dir_raw_e2="/home/ivar/Desktop/temp/render/EPI_raw_DSC/e2"
# render raw_cbv_files_e2 raw_label_files_e2 render_dir_raw_e2
# sleep 1
# render_dir_topup_e1="/home/ivar/Desktop/temp/render/EPI_applytopup/e1"
# render topup_cbv_files_e1 topup_label_files_e1 render_dir_topup_e1
# sleep 1
# render_dir_topup_e2="/home/ivar/Desktop/temp/render/EPI_applytopup/e2"
# render topup_cbv_files_e2 topup_label_files_e2 render_dir_topup_e2
# sleep 1
# render_dir_epic_e1="/home/ivar/Desktop/temp/render/EPI_applyepic/e1"
# render epic_cbv_files_e1 epic_label_files_e1 render_dir_epic_e1
# sleep 1
# render_dir_epic_e2="/home/ivar/Desktop/temp/render/EPI_applyepic/e2"
# render epic_cbv_files_e2 epic_label_files_e2 render_dir_epic_e2
# Out:
# --Finished rendering volume 0 to .png--
# --Finished rendering volume 1 to .png--
# --Finished rendering volume 2 to .png--
# --Finished rendering volume 3 to .png--
# --Finished rendering volume 4 to .png--
# --Finished rendering volume 5 to .png--
# --Finished rendering volume 6 to .png--
# --Finished rendering volume 7 to .png--
# --Finished rendering volume 8 to .png--
# --Finished rendering volume 9 to .png--
# --Finished rendering volume 10 to .png--
# --Finished rendering volume 11 to .png--
# --Finished rendering volume 12 to .png--
# --Finished rendering volume 13 to .png--
# --Finished rendering volume 14 to .png--
# --Finished rendering volume 15 to .png--
# --Finished rendering volume 16 to .png--
# --Finished rendering volume 17 to .png--
# --Finished rendering volume 18 to .png--
# --Finished rendering volume 19 to .png--
# --Finished rendering volume 20 to .png--
# --Finished rendering volume 21 to .png--
# --Finished rendering volume 22 to .png--
# --Finished rendering volume 23 to .png--
# --Finished rendering volume 24 to .png--
# --Finished rendering volume 25 to .png--
# --Finished rendering volume 26 to .png--
# --Finished rendering volume 27 to .png--
# --Finished rendering volume 28 to .png--
# --Finished rendering volume 29 to .png--
# --Finished rendering volume 30 to .png--
# --Finished rendering volume 31 to .png--
# --Finished rendering volume 32 to .png--
# --Finished rendering volume 33 to .png--
# --Finished rendering volume 34 to .png--
# --Finished rendering volume 35 to .png--
# --Finished rendering volume 36 to .png--
# --Finished rendering volume 37 to .png--
# --Finished rendering volume 38 to .png--
# --Finished rendering volume 39 to .png--
# --Finished rendering volume 40 to .png--
# --Finished rendering volume 41 to .png--
# --Finished rendering volume 42 to .png--
# --Finished rendering volume 43 to .png--
# --Finished rendering volume 44 to .png--
# --Finished rendering pngs to video--
# --Finished rendering volume 0 to .png--
# --Finished rendering volume 1 to .png--
# --Finished rendering volume 2 to .png--
# --Finished rendering volume 3 to .png--
# --Finished rendering volume 4 to .png--
# --Finished rendering volume 5 to .png--
# --Finished rendering volume 6 to .png--
# --Finished rendering volume 7 to .png--
# --Finished rendering volume 8 to .png--
# --Finished rendering volume 9 to .png--
# --Finished rendering volume 10 to .png--
# --Finished rendering volume 11 to .png--
# --Finished rendering volume 12 to .png--
# --Finished rendering volume 13 to .png--
# --Finished rendering volume 14 to .png--
# --Finished rendering volume 15 to .png--
# --Finished rendering volume 16 to .png--
# --Finished rendering volume 17 to .png--
# --Finished rendering volume 18 to .png--
# --Finished rendering volume 19 to .png--
# --Finished rendering volume 20 to .png--
# --Finished rendering volume 21 to .png--
# --Finished rendering volume 22 to .png--
# --Finished rendering volume 23 to .png--
# --Finished rendering volume 24 to .png--
# --Finished rendering volume 25 to .png--
# --Finished rendering volume 26 to .png--
# --Finished rendering volume 27 to .png--
# --Finished rendering volume 28 to .png--
# --Finished rendering volume 29 to .png--
# --Finished rendering volume 30 to .png--
# --Finished rendering volume 31 to .png--
# --Finished rendering volume 32 to .png--
# --Finished rendering volume 33 to .png--
# --Finished rendering volume 34 to .png--
# --Finished rendering volume 35 to .png--
# --Finished rendering volume 36 to .png--
# --Finished rendering volume 37 to .png--
# --Finished rendering volume 38 to .png--
# --Finished rendering volume 39 to .png--
# --Finished rendering volume 40 to .png--
# --Finished rendering volume 41 to .png--
# --Finished rendering volume 42 to .png--
# --Finished rendering volume 43 to .png--
# --Finished rendering volume 44 to .png--
# --Finished rendering pngs to video--
# --Finished rendering volume 0 to .png--
# --Finished rendering volume 1 to .png--
# --Finished rendering volume 2 to .png--
# --Finished rendering volume 3 to .png--
# --Finished rendering volume 4 to .png--
# --Finished rendering volume 5 to .png--
# --Finished rendering volume 6 to .png--
# --Finished rendering volume 7 to .png--
# --Finished rendering volume 8 to .png--
# --Finished rendering volume 9 to .png--
# --Finished rendering volume 10 to .png--
# --Finished rendering volume 11 to .png--
# --Finished rendering volume 12 to .png--
# --Finished rendering volume 13 to .png--
# --Finished rendering volume 14 to .png--
# --Finished rendering volume 15 to .png--
# --Finished rendering volume 16 to .png--
# --Finished rendering volume 17 to .png--
# --Finished rendering volume 18 to .png--
# --Finished rendering volume 19 to .png--
# --Finished rendering volume 20 to .png--
# --Finished rendering volume 21 to .png--
# --Finished rendering volume 22 to .png--
# --Finished rendering volume 23 to .png--
# --Finished rendering volume 24 to .png--
# --Finished rendering volume 25 to .png--
# --Finished rendering volume 26 to .png--
# --Finished rendering volume 27 to .png--
# --Finished rendering volume 28 to .png--
# --Finished rendering volume 29 to .png--
# --Finished rendering volume 30 to .png--
# --Finished rendering volume 31 to .png--
# --Finished rendering volume 32 to .png--
# --Finished rendering volume 33 to .png--
# --Finished rendering volume 34 to .png--
# --Finished rendering volume 35 to .png--
# --Finished rendering volume 36 to .png--
# --Finished rendering volume 37 to .png--
# --Finished rendering volume 38 to .png--
# --Finished rendering volume 39 to .png--
# --Finished rendering volume 40 to .png--
# --Finished rendering volume 41 to .png--
# --Finished rendering volume 42 to .png--
# --Finished rendering volume 43 to .png--
# --Finished rendering volume 44 to .png--
# --Finished rendering pngs to video--
# --Finished rendering volume 0 to .png--
# --Finished rendering volume 1 to .png--
# --Finished rendering volume 2 to .png--
# --Finished rendering volume 3 to .png--
# --Finished rendering volume 4 to .png--
# --Finished rendering volume 5 to .png--
# --Finished rendering volume 6 to .png--
# --Finished rendering volume 7 to .png--
# --Finished rendering volume 8 to .png--
# --Finished rendering volume 9 to .png--
# --Finished rendering volume 10 to .png--
# --Finished rendering volume 11 to .png--
# --Finished rendering volume 12 to .png--
# --Finished rendering volume 13 to .png--
# --Finished rendering volume 14 to .png--
# --Finished rendering volume 15 to .png--
# --Finished rendering volume 16 to .png--
# --Finished rendering volume 17 to .png--
# --Finished rendering volume 18 to .png--
# --Finished rendering volume 19 to .png--
# --Finished rendering volume 20 to .png--
# --Finished rendering volume 21 to .png--
# --Finished rendering volume 22 to .png--
# --Finished rendering volume 23 to .png--
# --Finished rendering volume 24 to .png--
# --Finished rendering volume 25 to .png--
# --Finished rendering volume 26 to .png--
# --Finished rendering volume 27 to .png--
# --Finished rendering volume 28 to .png--
# --Finished rendering volume 29 to .png--
# --Finished rendering volume 30 to .png--
# --Finished rendering volume 31 to .png--
# --Finished rendering volume 32 to .png--
# --Finished rendering volume 33 to .png--
# --Finished rendering volume 34 to .png--
# --Finished rendering volume 35 to .png--
# --Finished rendering volume 36 to .png--
# --Finished rendering volume 37 to .png--
# --Finished rendering volume 38 to .png--
# --Finished rendering volume 39 to .png--
# --Finished rendering volume 40 to .png--
# --Finished rendering volume 41 to .png--
# --Finished rendering volume 42 to .png--
# --Finished rendering volume 43 to .png--
# --Finished rendering volume 44 to .png--
# --Finished rendering pngs to video--
# --Finished rendering volume 0 to .png--
# --Finished rendering volume 1 to .png--
# --Finished rendering volume 2 to .png--
# --Finished rendering volume 3 to .png--
# --Finished rendering volume 4 to .png--
# --Finished rendering volume 5 to .png--
# --Finished rendering volume 6 to .png--
# --Finished rendering volume 7 to .png--
# --Finished rendering volume 8 to .png--
# --Finished rendering volume 9 to .png--
# --Finished rendering volume 10 to .png--
# --Finished rendering volume 11 to .png--
# --Finished rendering volume 12 to .png--
# --Finished rendering volume 13 to .png--
# --Finished rendering volume 14 to .png--
# --Finished rendering volume 15 to .png--
# --Finished rendering volume 16 to .png--
# --Finished rendering volume 17 to .png--
# --Finished rendering volume 18 to .png--
# --Finished rendering volume 19 to .png--
# --Finished rendering volume 20 to .png--
# --Finished rendering volume 21 to .png--
# --Finished rendering volume 22 to .png--
# --Finished rendering volume 23 to .png--
# --Finished rendering volume 24 to .png--
# --Finished rendering volume 25 to .png--
# --Finished rendering volume 26 to .png--
# --Finished rendering volume 27 to .png--
# --Finished rendering volume 28 to .png--
# --Finished rendering volume 29 to .png--
# --Finished rendering volume 30 to .png--
# --Finished rendering volume 31 to .png--
# --Finished rendering volume 32 to .png--
# --Finished rendering volume 33 to .png--
# --Finished rendering volume 34 to .png--
# --Finished rendering volume 35 to .png--
# --Finished rendering volume 36 to .png--
# --Finished rendering volume 37 to .png--
# --Finished rendering volume 38 to .png--
# --Finished rendering volume 39 to .png--
# --Finished rendering volume 40 to .png--
# --Finished rendering volume 41 to .png--
# --Finished rendering volume 42 to .png--
# --Finished rendering volume 43 to .png--
# --Finished rendering volume 44 to .png--
# --Finished rendering pngs to video--
# --Finished rendering volume 0 to .png--
# --Finished rendering volume 1 to .png--
# --Finished rendering volume 2 to .png--
# --Finished rendering volume 3 to .png--
# --Finished rendering volume 4 to .png--
# --Finished rendering volume 5 to .png--
# --Finished rendering volume 6 to .png--
# --Finished rendering volume 7 to .png--
# --Finished rendering volume 8 to .png--
# --Finished rendering volume 9 to .png--
# --Finished rendering volume 10 to .png--
# --Finished rendering volume 11 to .png--
# --Finished rendering volume 12 to .png--
# --Finished rendering volume 13 to .png--
# --Finished rendering volume 14 to .png--
# --Finished rendering volume 15 to .png--
# --Finished rendering volume 16 to .png--
# --Finished rendering volume 17 to .png--
# --Finished rendering volume 18 to .png--
# --Finished rendering volume 19 to .png--
# --Finished rendering volume 20 to .png--
# --Finished rendering volume 21 to .png--
# --Finished rendering volume 22 to .png--
# --Finished rendering volume 23 to .png--
# --Finished rendering volume 24 to .png--
# --Finished rendering volume 25 to .png--
# --Finished rendering volume 26 to .png--
# --Finished rendering volume 27 to .png--
# --Finished rendering volume 28 to .png--
# --Finished rendering volume 29 to .png--
# --Finished rendering volume 30 to .png--
# --Finished rendering volume 31 to .png--
# --Finished rendering volume 32 to .png--
# --Finished rendering volume 33 to .png--
# --Finished rendering volume 34 to .png--
# --Finished rendering volume 35 to .png--
# --Finished rendering volume 36 to .png--
# --Finished rendering volume 37 to .png--
# --Finished rendering volume 38 to .png--
# --Finished rendering volume 39 to .png--
# --Finished rendering volume 40 to .png--
# --Finished rendering volume 41 to .png--
# --Finished rendering volume 42 to .png--
# --Finished rendering volume 43 to .png--
# --Finished rendering volume 44 to .png--
# --Finished rendering pngs to video--
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/home/ivar/Desktop/temp/render/EPI_raw_DSC/e1/output_%03d.png':
#   Duration: 00:00:45.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 799x600 [SAR 3937:3937 DAR 799:600], 1 fps, 1 tbr, 1 tbn, 1 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x562082f6a6e0] using SAR=1/1
# [libx264 @ 0x562082f6a6e0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x562082f6a6e0] profile High, level 4.0
# [libx264 @ 0x562082f6a6e0] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=1 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/ivar/Desktop/temp/render/EPI_raw_DSC/e1/video.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 800x600 [SAR 1:1 DAR 4:3], q=-1--1, 1 fps, 16384 tbn, 1 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   45 fps= 25 q=-1.0 L00000000000000000000000000000000size=    3490kB time=00:00:42.00 bitrate= 680.7kbits/s speed=23.3x
# video:3489kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.038939%
# [libx264 @ 0x562082f6a6e0] frame I:3     Avg QP: 0.85  size: 88640
# [libx264 @ 0x562082f6a6e0] frame P:13    Avg QP: 1.13  size: 82531
# [libx264 @ 0x562082f6a6e0] frame B:29    Avg QP: 1.32  size: 76992
# [libx264 @ 0x562082f6a6e0] consecutive B-frames: 11.1%  0.0% 26.7% 62.2%
# [libx264 @ 0x562082f6a6e0] mb I  I16..4: 71.4%  0.2% 28.5%
# [libx264 @ 0x562082f6a6e0] mb P  I16..4:  4.1%  0.1% 14.3%  P16..4:  6.0%  3.0%  4.1%  0.0%  0.0%    skip:68.3%
# [libx264 @ 0x562082f6a6e0] mb B  I16..4:  1.9%  0.1% 13.0%  B16..8:  6.4%  2.0%  4.6%  direct: 2.9%  skip:69.1%  L0:53.9% L1:36.6% BI: 9.5%
# [libx264 @ 0x562082f6a6e0] 8x8 transform intra:0.4% inter:3.5%
# [libx264 @ 0x562082f6a6e0] direct mvs  spatial:82.8% temporal:17.2%
# [libx264 @ 0x562082f6a6e0] coded y,uvDC,uvAC intra: 59.2% 59.6% 59.5% inter: 10.2% 13.6% 13.5%
# [libx264 @ 0x562082f6a6e0] i16 v,h,dc,p: 89%  8%  3%  0%
# [libx264 @ 0x562082f6a6e0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 41% 17% 23%  2%  2%  2%  8%  4%  1%
# [libx264 @ 0x562082f6a6e0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 40% 27% 12%  4%  4%  4%  3%  4%  4%
# [libx264 @ 0x562082f6a6e0] i8c dc,h,v,p: 63% 16% 14%  7%
# [libx264 @ 0x562082f6a6e0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x562082f6a6e0] ref P L0: 36.1%  3.2% 28.4% 20.9% 10.6%  0.8%
# [libx264 @ 0x562082f6a6e0] ref B L0: 50.0% 30.9% 15.2%  3.9%
# [libx264 @ 0x562082f6a6e0] ref B L1: 88.2% 11.8%
# [libx264 @ 0x562082f6a6e0] kb/s:634.95
# bash: line 104: ep: command not found
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/home/ivar/Desktop/temp/render/EPI_raw_DSC/e2/output_%03d.png':
#   Duration: 00:00:45.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 799x600 [SAR 3937:3937 DAR 799:600], 1 fps, 1 tbr, 1 tbn, 1 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56056c3686e0] using SAR=1/1
# [libx264 @ 0x56056c3686e0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56056c3686e0] profile High, level 4.0
# [libx264 @ 0x56056c3686e0] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=1 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/ivar/Desktop/temp/render/EPI_raw_DSC/e2/video.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 800x600 [SAR 1:1 DAR 4:3], q=-1--1, 1 fps, 16384 tbn, 1 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   45 fps= 20 q=-1.0 L00000000000000000000000000000000size=    3124kB time=00:00:42.00 bitrate= 609.3kbits/s speed=  19x
# video:3122kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.044255%
# [libx264 @ 0x56056c3686e0] frame I:1     Avg QP: 0.16  size: 81602
# [libx264 @ 0x56056c3686e0] frame P:15    Avg QP: 0.54  size: 67481
# [libx264 @ 0x56056c3686e0] frame B:29    Avg QP: 1.20  size: 72513
# [libx264 @ 0x56056c3686e0] consecutive B-frames:  6.7% 17.8% 13.3% 62.2%
# [libx264 @ 0x56056c3686e0] mb I  I16..4: 71.2%  0.1% 28.7%
# [libx264 @ 0x56056c3686e0] mb P  I16..4:  6.0%  0.1% 10.1%  P16..4:  8.0%  4.2%  4.9%  0.0%  0.0%    skip:66.8%
# [libx264 @ 0x56056c3686e0] mb B  I16..4:  1.1%  0.1% 10.7%  B16..8:  7.0%  3.1%  4.7%  direct: 3.8%  skip:69.5%  L0:61.0% L1:27.6% BI:11.4%
# [libx264 @ 0x56056c3686e0] 8x8 transform intra:0.5% inter:4.4%
# [libx264 @ 0x56056c3686e0] direct mvs  spatial:79.3% temporal:20.7%
# [libx264 @ 0x56056c3686e0] coded y,uvDC,uvAC intra: 64.5% 66.0% 66.0% inter: 14.3% 17.8% 17.7%
# [libx264 @ 0x56056c3686e0] i16 v,h,dc,p: 84% 13%  3%  0%
# [libx264 @ 0x56056c3686e0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 38% 19% 21%  4%  3%  2%  4%  5%  4%
# [libx264 @ 0x56056c3686e0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 42% 27% 12%  3%  4%  3%  3%  3%  3%
# [libx264 @ 0x56056c3686e0] i8c dc,h,v,p: 54% 20% 18%  8%
# [libx264 @ 0x56056c3686e0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56056c3686e0] ref P L0: 34.5%  5.6% 20.0% 22.4% 15.1%  2.4%
# [libx264 @ 0x56056c3686e0] ref B L0: 41.6% 32.6% 21.8%  4.0%
# [libx264 @ 0x56056c3686e0] ref B L1: 88.0% 12.0%
# [libx264 @ 0x56056c3686e0] kb/s:568.30
# bash: line 107: ep: command not found
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/home/ivar/Desktop/temp/render/EPI_applytopup/e1/output_%03d.png':
#   Duration: 00:00:45.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 799x600 [SAR 3937:3937 DAR 799:600], 1 fps, 1 tbr, 1 tbn, 1 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x557e7e9e26e0] using SAR=1/1
# [libx264 @ 0x557e7e9e26e0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x557e7e9e26e0] profile High, level 4.0
# [libx264 @ 0x557e7e9e26e0] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=1 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/ivar/Desktop/temp/render/EPI_applytopup/e1/video.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 800x600 [SAR 1:1 DAR 4:3], q=-1--1, 1 fps, 16384 tbn, 1 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   45 fps= 22 q=-1.0 L00000000000000000000000000000000size=    3537kB time=00:00:42.00 bitrate= 689.9kbits/s speed=20.7x
# video:3536kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.037534%
# [libx264 @ 0x557e7e9e26e0] frame I:4     Avg QP: 0.96  size: 97783
# [libx264 @ 0x557e7e9e26e0] frame P:20    Avg QP: 1.02  size: 80517
# [libx264 @ 0x557e7e9e26e0] frame B:21    Avg QP: 1.35  size: 77076
# [libx264 @ 0x557e7e9e26e0] consecutive B-frames: 31.1% 13.3% 20.0% 35.6%
# [libx264 @ 0x557e7e9e26e0] mb I  I16..4: 70.1%  0.1% 29.8%
# [libx264 @ 0x557e7e9e26e0] mb P  I16..4: 14.8%  0.2% 15.2%  P16..4:  7.8%  2.8%  3.9%  0.0%  0.0%    skip:55.3%
# [libx264 @ 0x557e7e9e26e0] mb B  I16..4:  0.4%  0.1% 12.9%  B16..8:  9.0%  2.1%  4.3%  direct: 3.2%  skip:68.1%  L0:61.6% L1:31.7% BI: 6.6%
# [libx264 @ 0x557e7e9e26e0] 8x8 transform intra:0.4% inter:2.8%
# [libx264 @ 0x557e7e9e26e0] direct mvs  spatial:81.0% temporal:19.0%
# [libx264 @ 0x557e7e9e26e0] coded y,uvDC,uvAC intra: 47.7% 47.5% 47.4% inter: 10.7% 14.3% 14.3%
# [libx264 @ 0x557e7e9e26e0] i16 v,h,dc,p: 94%  4%  2%  0%
# [libx264 @ 0x557e7e9e26e0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 39% 22% 26%  2%  3%  2%  3%  2%  1%
# [libx264 @ 0x557e7e9e26e0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 40% 27% 12%  4%  4%  4%  3%  4%  3%
# [libx264 @ 0x557e7e9e26e0] i8c dc,h,v,p: 70% 13% 11%  6%
# [libx264 @ 0x557e7e9e26e0] Weighted P-Frames: Y:10.0% UV:5.0%
# [libx264 @ 0x557e7e9e26e0] ref P L0: 22.2%  3.9% 24.7% 28.4% 10.4% 10.4%
# [libx264 @ 0x557e7e9e26e0] ref B L0: 33.9% 34.8% 25.2%  6.0%
# [libx264 @ 0x557e7e9e26e0] ref B L1: 92.6%  7.4%
# [libx264 @ 0x557e7e9e26e0] kb/s:643.57
# bash: line 110: ep: command not found
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/home/ivar/Desktop/temp/render/EPI_applytopup/e2/output_%03d.png':
#   Duration: 00:00:45.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 799x600 [SAR 3937:3937 DAR 799:600], 1 fps, 1 tbr, 1 tbn, 1 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55e03bbc5a00] using SAR=1/1
# [libx264 @ 0x55e03bbc5a00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55e03bbc5a00] profile High, level 4.0
# [libx264 @ 0x55e03bbc5a00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=1 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/ivar/Desktop/temp/render/EPI_applytopup/e2/video.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 800x600 [SAR 1:1 DAR 4:3], q=-1--1, 1 fps, 16384 tbn, 1 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   45 fps= 27 q=-1.0 L00000000000000000000000000000000size=    3068kB time=00:00:42.00 bitrate= 598.4kbits/s speed=25.5x
# video:3066kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.044682%
# [libx264 @ 0x55e03bbc5a00] frame I:2     Avg QP: 0.24  size: 81120
# [libx264 @ 0x55e03bbc5a00] frame P:13    Avg QP: 0.46  size: 67845
# [libx264 @ 0x55e03bbc5a00] frame B:30    Avg QP: 1.00  size: 69834
# [libx264 @ 0x55e03bbc5a00] consecutive B-frames:  6.7%  4.4% 26.7% 62.2%
# [libx264 @ 0x55e03bbc5a00] mb I  I16..4: 70.7%  0.2% 29.2%
# [libx264 @ 0x55e03bbc5a00] mb P  I16..4:  4.4%  0.1% 10.9%  P16..4:  8.7%  4.1%  4.7%  0.0%  0.0%    skip:67.1%
# [libx264 @ 0x55e03bbc5a00] mb B  I16..4:  0.5%  0.1% 10.2%  B16..8:  6.8%  3.1%  4.7%  direct: 3.6%  skip:71.0%  L0:61.4% L1:27.2% BI:11.5%
# [libx264 @ 0x55e03bbc5a00] 8x8 transform intra:0.5% inter:3.6%
# [libx264 @ 0x55e03bbc5a00] direct mvs  spatial:80.0% temporal:20.0%
# [libx264 @ 0x55e03bbc5a00] coded y,uvDC,uvAC intra: 63.7% 62.4% 62.3% inter: 13.5% 17.1% 17.0%
# [libx264 @ 0x55e03bbc5a00] i16 v,h,dc,p: 90%  6%  4%  0%
# [libx264 @ 0x55e03bbc5a00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 46% 18% 18%  2%  3%  3%  2%  5%  3%
# [libx264 @ 0x55e03bbc5a00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 42% 27% 11%  3%  4%  3%  3%  3%  3%
# [libx264 @ 0x55e03bbc5a00] i8c dc,h,v,p: 59% 17% 16%  8%
# [libx264 @ 0x55e03bbc5a00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55e03bbc5a00] ref P L0: 33.5%  5.7% 28.2% 19.2% 12.6%  0.9%
# [libx264 @ 0x55e03bbc5a00] ref B L0: 44.7% 29.4% 18.9%  6.9%
# [libx264 @ 0x55e03bbc5a00] ref B L1: 87.9% 12.1%
# [libx264 @ 0x55e03bbc5a00] kb/s:558.09
# bash: line 113: ep: command not found
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/home/ivar/Desktop/temp/render/EPI_applyepic/e1/output_%03d.png':
#   Duration: 00:00:45.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 799x600 [SAR 3937:3937 DAR 799:600], 1 fps, 1 tbr, 1 tbn, 1 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x562d0926f6e0] using SAR=1/1
# [libx264 @ 0x562d0926f6e0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x562d0926f6e0] profile High, level 4.0
# [libx264 @ 0x562d0926f6e0] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=1 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/ivar/Desktop/temp/render/EPI_applyepic/e1/video.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 800x600 [SAR 1:1 DAR 4:3], q=-1--1, 1 fps, 16384 tbn, 1 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   45 fps= 23 q=-1.0 L00000000000000000000000000000000size=    3501kB time=00:00:42.00 bitrate= 682.8kbits/s speed=21.7x
# video:3500kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.039151%
# [libx264 @ 0x562d0926f6e0] frame I:3     Avg QP: 0.65  size: 93823
# [libx264 @ 0x562d0926f6e0] frame P:18    Avg QP: 0.88  size: 80645
# [libx264 @ 0x562d0926f6e0] frame B:24    Avg QP: 1.23  size: 77074
# [libx264 @ 0x562d0926f6e0] consecutive B-frames: 20.0% 22.2% 13.3% 44.4%
# [libx264 @ 0x562d0926f6e0] mb I  I16..4: 71.1%  0.1% 28.7%
# [libx264 @ 0x562d0926f6e0] mb P  I16..4: 20.0%  0.1% 15.6%  P16..4:  6.2%  2.8%  4.0%  0.0%  0.0%    skip:51.3%
# [libx264 @ 0x562d0926f6e0] mb B  I16..4:  0.3%  0.0% 12.5%  B16..8:  5.9%  2.2%  4.8%  direct: 2.8%  skip:71.5%  L0:58.3% L1:32.2% BI: 9.5%
# [libx264 @ 0x562d0926f6e0] 8x8 transform intra:0.3% inter:2.8%
# [libx264 @ 0x562d0926f6e0] direct mvs  spatial:75.0% temporal:25.0%
# [libx264 @ 0x562d0926f6e0] coded y,uvDC,uvAC intra: 47.3% 48.1% 48.0% inter: 10.7% 14.2% 14.2%
# [libx264 @ 0x562d0926f6e0] i16 v,h,dc,p: 94%  5%  2%  0%
# [libx264 @ 0x562d0926f6e0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 22% 23%  2%  3%  3%  5%  7%  1%
# [libx264 @ 0x562d0926f6e0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 40% 27% 12%  4%  4%  4%  3%  4%  4%
# [libx264 @ 0x562d0926f6e0] i8c dc,h,v,p: 70% 13% 12%  6%
# [libx264 @ 0x562d0926f6e0] Weighted P-Frames: Y:22.2% UV:16.7%
# [libx264 @ 0x562d0926f6e0] ref P L0: 26.0%  2.9% 22.3% 18.9% 21.4%  6.2%  2.2%
# [libx264 @ 0x562d0926f6e0] ref B L0: 46.0% 31.1% 18.5%  4.5%
# [libx264 @ 0x562d0926f6e0] ref B L1: 86.7% 13.3%
# [libx264 @ 0x562d0926f6e0] kb/s:636.95
# bash: line 116: ep: command not found
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/home/ivar/Desktop/temp/render/EPI_applyepic/e2/output_%03d.png':
#   Duration: 00:00:45.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 799x600 [SAR 3937:3937 DAR 799:600], 1 fps, 1 tbr, 1 tbn, 1 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x561c11f256e0] using SAR=1/1
# [libx264 @ 0x561c11f256e0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x561c11f256e0] profile High, level 4.0
# [libx264 @ 0x561c11f256e0] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=1 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/ivar/Desktop/temp/render/EPI_applyepic/e2/video.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 800x600 [SAR 1:1 DAR 4:3], q=-1--1, 1 fps, 16384 tbn, 1 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   45 fps= 19 q=-1.0 Lsize=    3133kB time=00:00:42.00 bitrate= 611.0kbits/s speed=18.2x
# video:3131kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.043882%
# [libx264 @ 0x561c11f256e0] frame I:2     Avg QP: 0.31  size: 87378
# [libx264 @ 0x561c11f256e0] frame P:14    Avg QP: 0.53  size: 70140
# [libx264 @ 0x561c11f256e0] frame B:29    Avg QP: 0.91  size: 70653
# [libx264 @ 0x561c11f256e0] consecutive B-frames: 11.1%  8.9%  0.0% 80.0%
# [libx264 @ 0x561c11f256e0] mb I  I16..4: 70.6%  0.1% 29.3%
# [libx264 @ 0x561c11f256e0] mb P  I16..4: 13.6%  0.2% 12.2%  P16..4:  9.2%  4.0%  4.5%  0.0%  0.0%    skip:56.4%
# [libx264 @ 0x561c11f256e0] mb B  I16..4:  0.6%  0.1% 10.8%  B16..8:  7.2%  3.1%  4.7%  direct: 3.7%  skip:70.0%  L0:57.4% L1:30.5% BI:12.0%
# [libx264 @ 0x561c11f256e0] 8x8 transform intra:0.5% inter:4.4%
# [libx264 @ 0x561c11f256e0] direct mvs  spatial:79.3% temporal:20.7%
# [libx264 @ 0x561c11f256e0] coded y,uvDC,uvAC intra: 54.5% 54.7% 54.6% inter: 14.1% 17.7% 17.6%
# [libx264 @ 0x561c11f256e0] i16 v,h,dc,p: 92%  5%  2%  0%
# [libx264 @ 0x561c11f256e0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 21% 26%  3%  3%  4%  4%  4%  2%
# [libx264 @ 0x561c11f256e0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 42% 27% 12%  3%  4%  3%  3%  3%  3%
# [libx264 @ 0x561c11f256e0] i8c dc,h,v,p: 64% 15% 14%  7%
# [libx264 @ 0x561c11f256e0] Weighted P-Frames: Y:14.3% UV:7.1%
# [libx264 @ 0x561c11f256e0] ref P L0: 30.5%  4.6% 22.3% 20.6% 17.8%  4.3%
# [libx264 @ 0x561c11f256e0] ref B L0: 45.6% 34.2% 16.3%  4.0%
# [libx264 @ 0x561c11f256e0] ref B L1: 87.4% 12.6%
# [libx264 @ 0x561c11f256e0] kb/s:569.90
