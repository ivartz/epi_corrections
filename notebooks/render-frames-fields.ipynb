# %% [markdown]
# This notebook contains code for rendering .png images according to a predefined fsleyes orthographic view, of 3D-FLAIR based MNI normalized TOPUP and EPIC field maps overlayed on a MNI brain regions template. It also uses ffmpeg to make videos of the images.

# %% [markdown]
# 1. Specify epi_corrections output directory

# %%
output_directory_suffix = "2019_07_02"
# On local file system:
corrections_base_directory = "../../epi_corrections_out_" + output_directory_suffix
# On samba share (remote file sytem):
#corrections_base_directory = "/run/user/1000/gvfs/smb-share:server=192.168.1.207,share=hdd3tb1/data/IVS_EPI_BASELINE/epi_corrections_out_" + output_directory_suffix
corrections_base_directory
# Out:
# '../../epi_corrections_out_2019_07_02'

# %% [markdown]
# 2. Since nICE introduced files with spaces in their file names,
# recursively replace spaces in folders and file names.
# The fsleyes rendering bash command did not accept
# spaces in file names and directories.

# %%
from utils import replace_spaces_with_underscore
replace_spaces_with_underscore(corrections_base_directory + "/EPI_raw_DSC")
replace_spaces_with_underscore(corrections_base_directory + "/EPI_applytopup")
replace_spaces_with_underscore(corrections_base_directory + "/EPI_applyepic")

# %% [markdown]
# 3. Find the MNI-normalized, NordicICE intensity Normalized Relative CBV files. Can be done remotely.

# %%
from search import find_field_files

[topup_field_files_e1, \
 epic_field_files_e1, \
 topup_field_files_e2, \
 epic_field_files_e2] = find_field_files(corrections_base_directory)

# %%
# A check
print("Equal number of detected field files for topup, and epic correction methods: %r" % \
      (len(topup_field_files_e1) == \
       len(topup_field_files_e2) == \
       len(epic_field_files_e1) == \
       len(epic_field_files_e2)))
print("Number of subject field files: %i" % len(topup_field_files_e1))
# Out:
# Equal number of detected field files for topup, and epic correction methods: True
# Number of subject field files: 45

# %% [markdown]
# 4. Find the corresponding MNI label files
# (should perhaps be identical to each other, but just to make sure..)

# %%
from search import find_label_files

[raw_label_files_e1, \
 topup_label_files_e1, \
 epic_label_files_e1, \
 raw_label_files_e2, \
 topup_label_files_e2, \
 epic_label_files_e2] = find_label_files(corrections_base_directory)

# %%
# A check
print("Equal number of detected label files for raw (uncorrected), topup, and epic correction methods: %r" % \
      (len(raw_label_files_e1) == \
       len(raw_label_files_e2) == \
       len(topup_label_files_e1) == \
       len(topup_label_files_e2) == \
       len(epic_label_files_e1) == \
       len(epic_label_files_e2)))
print("Number of subject label files: %i" % len(raw_label_files_e1))
# Out:
# Equal number of detected label files for raw (uncorrected), topup, and epic correction methods: True
# Number of subject label files: 45

# %% [markdown]
# 5. For the raw, topup and epic Gradient Echo (GE) and Spin Echo (SE) nrCBV data + MNI regions file, render .png images in a predefined orthographic view, then make a video. __Note:__ The following cells must run within a fsl X environment

# %%
# %%bash -s "{" ".join(topup_field_files_e1)}" "{" ".join(epic_field_files_e1)}" "{" ".join(topup_field_files_e2)}" "{" ".join(epic_field_files_e2)}" "{" ".join(topup_label_files_e1)}" "{" ".join(epic_label_files_e1)}" "{" ".join(topup_label_files_e2)}" "{" ".join(epic_label_files_e2)}"
# IFS=' ' read -r -a topup_field_files_e1 <<< "$1"
# IFS=' ' read -r -a epic_field_files_e1 <<< "$2"
# IFS=' ' read -r -a topup_field_files_e2 <<< "$3"
# IFS=' ' read -r -a epic_field_files_e2 <<< "$4"
# IFS=' ' read -r -a topup_label_files_e1 <<< "$5"
# IFS=' ' read -r -a epic_label_files_e1 <<< "$6"
# IFS=' ' read -r -a topup_label_files_e2 <<< "$7"
# IFS=' ' read -r -a epic_label_files_e2 <<< "$8"
# render() {
#     local -n _field_files=$1
#     local -n _label_files=$2
#     local -n _render_dir=$3
#
#     # Remove existing render directory.
#     if [ -d "$_render_dir" ]; then rm -rd "$_render_dir"; fi
#
#     mkdir -p "$_render_dir"
#
#     for index in "${!_field_files[@]}"
#     do
#         field_file="${_field_files[index]}"
#         label_file="${_label_files[index]}"
#
#         field_file_name="$(basename $field_file)"
#         label_file_name="$(basename $label_file)"
#
#         render_command='fsleyes
#             render
#             --outfile "'$_render_dir'/'output_$(printf "%03d\n" $index)'"
#             --scene ortho
#             --worldLoc 9.918212890625e-05 -18.000099182128906 7.999900817871094
#             --displaySpace
#             '$field_file'
#             --xcentre  0.00000  0.00000
#             --ycentre  0.00000  0.00000
#             --zcentre  0.00000 -0.00000
#             --xzoom 100.0
#             --yzoom 100.0
#             --zzoom 100.0
#             --hideLabels
#             --labelSize 14
#             --layout horizontal
#             --hideCursor
#             --bgColour 0.0 0.0 0.0
#             --fgColour 1.0 1.0 1.0
#             --cursorColour 0.0 1.0 0.0
#             --showColourBar
#             --colourBarLocation top
#             --colourBarLabelSide top-left
#             --performance 3
#             '$label_file'
#             --name '$label_file_name'
#             --overlayType volume
#             --alpha 100.0
#             --brightness 50.0
#             --contrast 50.0
#             --cmap greyscale
#             --negativeCmap greyscale
#             --displayRange 0.0 207.0
#             --clippingRange 0.0 209.07
#             --gamma 0.0
#             --cmapResolution 256
#             --interpolation none
#             --numSteps 100
#             --blendFactor 0.1
#             --smoothing 0
#             --resolution 100
#             --numInnerSteps 10
#             --clipMode intersection
#             --volume 0
#             '$field_file'
#             --name '$field_file_name'
#             --overlayType volume
#             --alpha 79.33333334031825
#             --brightness 54.09163686077013
#             --contrast 49.09314381711701
#             --cmap render3
#             --negativeCmap greyscale
#             --displayRange -6.0 6.0
#             --clippingRange -6.0 12.869085369110108
#             --gamma 0.0 --cmapResolution 256
#             --interpolation none
#             --numSteps 100
#             --blendFactor 0.1
#             --smoothing 0
#             --resolution 100
#             --numInnerSteps 10
#             --clipMode intersection
#             --volume 0'
#         echo $render_command >> "$_render_dir/commands.txt"
#         #echo $render_command
#         eval $render_command
#         echo "--Finished rendering volume $index to .png--"
#     done
#     ffmpeg -framerate 1 -i "$_render_dir"/output_%03d.png -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -c:v libx264 -preset slow -profile:v high -level:v 4.0 -pix_fmt yuv420p -crf 1 "$_render_dir"/video.mp4
#     echo "--Finished rendering pngs to video--"
# }
# render_dir_topup_field_e1="../../epi_corrections_out_2019_07_02/render_fields/TOPUP/e1"
# render topup_field_files_e1 topup_label_files_e1 render_dir_topup_field_e1
# sleep 2 # Sleep 1 second; this was necessary otherwise the next call of render() function did seem to get emtpy render dir argument...
# render_dir_topup_field_e2="../../epi_corrections_out_2019_07_02/render_fields/TOPUP/e2"
# render topup_field_files_e2 topup_label_files_e2 render_dir_topup_field_e2
# Out:
# --Finished rendering volume 0 to .png--
# --Finished rendering volume 1 to .png--
# --Finished rendering volume 2 to .png--
# --Finished rendering volume 3 to .png--
# --Finished rendering volume 4 to .png--
# --Finished rendering volume 5 to .png--
# --Finished rendering volume 6 to .png--
# --Finished rendering volume 7 to .png--
# --Finished rendering volume 8 to .png--
# --Finished rendering volume 9 to .png--
# --Finished rendering volume 10 to .png--
# --Finished rendering volume 11 to .png--
# --Finished rendering volume 12 to .png--
# --Finished rendering volume 13 to .png--
# --Finished rendering volume 14 to .png--
# --Finished rendering volume 15 to .png--
# --Finished rendering volume 16 to .png--
# --Finished rendering volume 17 to .png--
# --Finished rendering volume 18 to .png--
# --Finished rendering volume 19 to .png--
# --Finished rendering volume 20 to .png--
# --Finished rendering volume 21 to .png--
# --Finished rendering volume 22 to .png--
# --Finished rendering volume 23 to .png--
# --Finished rendering volume 24 to .png--
# --Finished rendering volume 25 to .png--
# --Finished rendering volume 26 to .png--
# --Finished rendering volume 27 to .png--
# --Finished rendering volume 28 to .png--
# --Finished rendering volume 29 to .png--
# --Finished rendering volume 30 to .png--
# --Finished rendering volume 31 to .png--
# --Finished rendering volume 32 to .png--
# --Finished rendering volume 33 to .png--
# --Finished rendering volume 34 to .png--
# --Finished rendering volume 35 to .png--
# --Finished rendering volume 36 to .png--
# --Finished rendering volume 37 to .png--
# --Finished rendering volume 38 to .png--
# --Finished rendering volume 39 to .png--
# --Finished rendering volume 40 to .png--
# --Finished rendering volume 41 to .png--
# --Finished rendering volume 42 to .png--
# --Finished rendering volume 43 to .png--
# --Finished rendering volume 44 to .png--
# --Finished rendering pngs to video--
# (wr_coregest_145923_GE-SE_EPI_SSH_v1_32CH_V2_scan_prescan_1001_901_e2_0000_prep_topup_field_postp.nii:31439): Gtk-CRITICAL **: 20:17:06.933: gtk_window_resize: assertion 'width > 0' failed
# 20:17:07: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_120520_GE-SE_EPI_SSH_v1_32CH_V2_scan_prescan_1101_901_e2_0000_prep_topup_field_postp.nii:31461): Gtk-CRITICAL **: 20:17:12.401: gtk_window_resize: assertion 'width > 0' failed
# 20:17:12: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_104123_GE-SE_EPI_SSH_v1_32CH_V2_scan_prescan_1001_901_e2_0000_prep_topup_field_postp.nii:31482): Gtk-CRITICAL **: 20:17:18.081: gtk_window_resize: assertion 'width > 0' failed
# 20:17:18: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_103709_WIP_GE-SE_EPI_SSH_v1_32CH_SENSE_corr_SENSE_1001_901_e2_0000_prep_topup_field_postp.nii:31505): Gtk-CRITICAL **: 20:17:23.743: gtk_window_resize: assertion 'width > 0' failed
# 20:17:23: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_144338_GE-SE_EPI_SSH_v1_32CH_V2_scan_prescan_1001_901_e2_0000_prep_topup_field_postp.nii:31529): Gtk-CRITICAL **: 20:17:29.070: gtk_window_resize: assertion 'width > 0' failed
# 20:17:29: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_122905_WIP_GE-SE_EPI_SSH_v1_32CH_SENSE_corr_SENSE_1001_901_e2_0000_prep_topup_field_postp.nii:31550): Gtk-CRITICAL **: 20:17:34.649: gtk_window_resize: assertion 'width > 0' failed
# 20:17:34: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_130326_GE-SE_EPI_SSH_v1_32CH_V2_scan_prescan_1401_901_e2_0000_prep_topup_field_postp.nii:31571): Gtk-CRITICAL **: 20:17:40.466: gtk_window_resize: assertion 'width > 0' failed
# 20:17:40: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_101356_GE-SE_EPI_SSH_v1_32CH_V2_scan_prescan_1001_901_e2_0000_prep_topup_field_postp.nii:31592): Gtk-CRITICAL **: 20:17:46.068: gtk_window_resize: assertion 'width > 0' failed
# 20:17:46: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_150118_GE-SE_EPI_SSH_v1_32CH_V2_scan_prescan_1201_1101_e2_0000_prep_topup_field_postp.nii:31622): Gtk-CRITICAL **: 20:17:52.001: gtk_window_resize: assertion 'width > 0' failed
# 20:17:52: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest
Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_154038_WIP_GE-SE_EPI_SSH_v1_32CH_SENSE_corr_SENSE_901_801_e2_0000_prep_topup_field_postp.nii:32083): Gtk-CRITICAL **: 20:19:49.086: gtk_window_resize: assertion 'width > 0' failed
# 20:19:49: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_135702_WIP_GE-SE_EPI_SSH_v1_32CH_SENSE_corr_SENSE_1001_901_e2_0000_prep_topup_field_postp.nii:32113): Gtk-CRITICAL **: 20:19:54.841: gtk_window_resize: assertion 'width > 0' failed
# 20:19:54: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_94900_GE-SE_EPI_SSH_v1_32CH_V2_scan_prescan_1001_901_e2_0000_prep_topup_field_postp.nii:32137): Gtk-CRITICAL **: 20:20:00.448: gtk_window_resize: assertion 'width > 0' failed
# 20:20:00: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_145901_WIP_GE-SE_EPI_SSH_16CH_SENSE_corr_SENSE_901_801_e2_0000_prep_topup_field_postp.nii:32158): Gtk-CRITICAL **: 20:20:05.885: gtk_window_resize: assertion 'width > 0' failed
# 20:20:06: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_131148_GE-SE_EPI_SSH_v1_32CH_V2_scan_prescan_1001_901_e2_0000_prep_topup_field_postp.nii:32179): Gtk-CRITICAL **: 20:20:11.790: gtk_window_resize: assertion 'width > 0' failed
# 20:20:11: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_142930_GE-SE_EPI_SSH_v1_32CH_V2_scan_prescan_1001_901_e2_0000_prep_topup_field_postp.nii:32201): Gtk-CRITICAL **: 20:20:17.540: gtk_window_resize: assertion 'width > 0' failed
# 20:20:17: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_141033_GE-SE_EPI_SSH_v1_32CH_V2_scan_prescan_1101_1001_e2_0000_prep_topup_field_postp.nii:32221): Gtk-CRITICAL **: 20:20:23.077: gtk_window_resize: assertion 'width > 0' failed
# 20:20:23: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_122448_GE-SE_EPI_SSH_v1_32CH_V2_scan_prescan_1001_901_e2_0000_prep_topup_field_postp.nii:32242): Gtk-CRITICAL **: 20:20:28.455: gtk_window_resize: assertion 'width > 0' failed
# 20:20:28: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_104935_WIP_GE-SE_EPI_SSH_v1_32CH_SENSE_corr_SENSE_801_701_e2_0000_prep_topup_field_postp.nii:32266): Gtk-CRITICAL **: 20:20:33.777: gtk_window_resize: assertion 'width > 0' failed
# 20:20:33: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_132957_WIP_GE-SE_EPI_SSH_v1_32CH_SENSE_corr_SENSE_801_701_e2_0000_prep_topup_field_postp.nii:32287): Gtk-CRITICAL **: 20:20:39.444: gtk_window_resize: assertion 'width > 0' failed
# 20:20:39: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_141049_WIP_GE-SE_EPI_SSH_v1_32CH_SENSE_corr_SENSE_701_601_e2_0000_prep_topup_field_postp.nii:32307): Gtk-CRITICAL **: 20:20:44.956: gtk_window_resize: assertion 'width > 0' failed
# 20:20:45: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_134014_GE-SE_EPI_SSH_v1_32CH_V2_scan_prescan_1001_901_e2_0000_prep_topup_field_postp.nii:32329): Gtk-CRITICAL **: 20:20:50.578: gtk_window_resize: assertion 'width > 0' failed
# 20:20:50: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_132210_WIP_GE-SE_EPI_SSH_v1_32CH_SENSE_corr_SENSE_801_701_e2_0000_prep_topup_field_postp.nii:32359): Gtk-CRITICAL **: 20:20:56.000: gtk_window_resize: assertion 'width > 0' failed
# 20:20:56: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_133945_GE-SE_EPI_SSH_v1_32CH_V2_scan_prescan_1001_901_e2_0000_prep_topup_field_postp.nii:32382): Gtk-CRITICAL **: 20:21:01.648: gtk_window_resize: assertion 'width > 0' failed
# 20:21:01: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_101256_WIP_GE-SE_EPI_SSH_v1_32CH_SENSE_corr_SENSE_701_601_e2_0000_prep_topup_field_postp.nii:32402): Gtk-CRITICAL **: 20:21:07.064: gtk_window_resize: assertion 'width > 0' failed
# 20:21:07: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_123601_GE-SE_EPI_SSH_v1_32CH_V2_scan_prescan_1001_901_e2_0000_prep_topup_field_postp.nii:32423): Gtk-CRITICAL **: 20:21:12.578: gtk_window_resize: assertion 'width > 0' failed
# 20:21:12: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
# ffmpeg version 4.0.4-0ubuntu1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 8 (Ubuntu 8.2.0-7ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, image2, from '../../epi_corrections_out_2019_07_02/render_fields/TOPUP/e2/output_%03d.png':
#   Duration: 00:00:45.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 800x600 [SAR 3937:3937 DAR 4:3], 1 fps, 1 tbr, 1 tbn, 1 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x561e2e6eb400] using SAR=1/1
# [libx264 @ 0x561e2e6eb400] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.1 Cache64
# [libx264 @ 0x561e2e6eb400] profile High, level 4.0
# [libx264 @ 0x561e2e6eb400] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=1 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../epi_corrections_out_2019_07_02/render_fields/TOPUP/e2/video.mp4':
#   Metadata:
#     encoder         : Lavf58.12.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 800x600 [SAR 1:1 DAR 4:3], q=-1--1, 1 fps, 16384 tbn, 1 tbc
#     Metadata:
#       encoder         : Lavc58.18.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   45 fps= 12 q=-1.0 Lsize=    3065kB time=00:00:42.00 bitrate= 597.8kbits/s speed=10.7x
# video:3063kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.045362%
# [libx264 @ 0x561e2e6eb400] frame I:1     Avg QP: 0.22  size: 93220
# [libx264 @ 0x561e2e6eb400] frame P:13    Avg QP: 1.16  size: 70175
# [libx264 @ 0x561e2e6eb400] frame B:31    Avg QP: 2.34  size: 68736
# [libx264 @ 0x561e2e6eb400] consecutive B-frames:  4.4%  8.9%  6.7% 80.0%
# [libx264 @ 0x561e2e6eb400] mb I  I16..4: 57.2%  0.1% 42.7%
# [libx264 @ 0x561e2e6eb400] mb P  I16..4:  3.2%  0.2% 15.1%  P16..4:  9.5%  4.7%  4.8%  0.0%  0.0%    skip:62.4%
# [libx264 @ 0x561e2e6eb400] mb B  I16..4:  1.3%  0.1% 14.9%  B16..8:  7.2%  3.3%  4.5%  direct: 5.0%  skip:63.7%  L0:60.3% L1:28.9% BI:10.8%
# [libx264 @ 0x561e2e6eb400] 8x8 transform intra:0.8% inter:8.3%
# [libx264 @ 0x561e2e6eb400] direct mvs  spatial:87.1% temporal:12.9%
# [libx264 @ 0x561e2e6eb400] coded y,uvDC,uvAC intra: 80.0% 79.2% 79.2% inter: 16.8% 17.1% 17.1%
# [libx264 @ 0x561e2e6eb400] i16 v,h,dc,p: 79% 18%  2%  1%
# [libx264 @ 0x561e2e6eb400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 41% 28% 15%  0%  2%  6%  2%  3%  3%
# [libx264 @ 0x561e2e6eb400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 42% 35%  9%  3%  3%  2%  2%  2%  2%
# [libx264 @ 0x561e2e6eb400] i8c dc,h,v,p: 34% 25% 25% 16%
# [libx264 @ 0x561e2e6eb400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x561e2e6eb400] ref P L0: 30.9%  6.2% 19.0% 20.8% 23.0%
# [libx264 @ 0x561e2e6eb400] ref B L0: 49.0% 28.1% 18.6%  4.3%
# [libx264 @ 0x561e2e6eb400] ref B L1: 82.8% 17.2%
# [libx264 @ 0x561e2e6eb400] kb/s:557.56

# %%
# %%bash -s "{" ".join(topup_field_files_e1)}" "{" ".join(epic_field_files_e1)}" "{" ".join(topup_field_files_e2)}" "{" ".join(epic_field_files_e2)}" "{" ".join(topup_label_files_e1)}" "{" ".join(epic_label_files_e1)}" "{" ".join(topup_label_files_e2)}" "{" ".join(epic_label_files_e2)}"
# IFS=' ' read -r -a topup_field_files_e1 <<< "$1"
# IFS=' ' read -r -a epic_field_files_e1 <<< "$2"
# IFS=' ' read -r -a topup_field_files_e2 <<< "$3"
# IFS=' ' read -r -a epic_field_files_e2 <<< "$4"
# IFS=' ' read -r -a topup_label_files_e1 <<< "$5"
# IFS=' ' read -r -a epic_label_files_e1 <<< "$6"
# IFS=' ' read -r -a topup_label_files_e2 <<< "$7"
# IFS=' ' read -r -a epic_label_files_e2 <<< "$8"
# render() {
#     local -n _field_files=$1
#     local -n _label_files=$2
#     local -n _render_dir=$3
#
#     # Remove existing render directory.
#     if [ -d "$_render_dir" ]; then rm -rd "$_render_dir"; fi
#
#     mkdir -p "$_render_dir"
#
#     for index in "${!_field_files[@]}"
#     do
#         field_file="${_field_files[index]}"
#         label_file="${_label_files[index]}"
#
#         field_file_name="$(basename $field_file)"
#         label_file_name="$(basename $label_file)"
#
#         render_command='fsleyes
#             render
#             --outfile "'$_render_dir'/'output_$(printf "%03d\n" $index)'"
#             --scene ortho
#             --worldLoc 9.918212890625e-05 -18.000099182128906 7.999900817871094
#             --displaySpace
#             '$field_file'
#             --xcentre  0.00000  0.00000
#             --ycentre  0.00000  0.00000
#             --zcentre  0.00000 -0.00000
#             --xzoom 100.0
#             --yzoom 100.0
#             --zzoom 100.0
#             --hideLabels
#             --labelSize 14
#             --layout horizontal
#             --hideCursor
#             --bgColour 0.0 0.0 0.0
#             --fgColour 1.0 1.0 1.0
#             --cursorColour 0.0 1.0 0.0
#             --showColourBar
#             --colourBarLocation top
#             --colourBarLabelSide top-left
#             --performance 3
#             '$label_file'
#             --name '$label_file_name'
#             --overlayType volume
#             --alpha 100.0
#             --brightness 50.0
#             --contrast 50.0
#             --cmap greyscale
#             --negativeCmap greyscale
#             --displayRange 0.0 207.0
#             --clippingRange 0.0 209.07
#             --gamma 0.0
#             --cmapResolution 256
#             --interpolation none
#             --numSteps 100
#             --blendFactor 0.1
#             --smoothing 0
#             --resolution 100
#             --numInnerSteps 10
#             --clipMode intersection
#             --volume 0
#             '$field_file'
#             --name '$field_file_name'
#             --overlayType volume
#             --alpha 79.33333334031825
#             --brightness 54.09163686077013
#             --contrast 49.09314381711701
#             --cmap render3
#             --negativeCmap greyscale
#             --displayRange -6.0 6.0
#             --clippingRange -6.0 6.505926780700683
#             --gamma 0.0 --cmapResolution 256
#             --interpolation none
#             --numSteps 100
#             --blendFactor 0.1
#             --smoothing 0
#             --resolution 100
#             --numInnerSteps 10
#             --clipMode intersection
#             --volume 0'
#         echo $render_command >> "$_render_dir/commands.txt"
#         #echo $render_command
#         eval $render_command
#         echo "--Finished rendering volume $index to .png--"
#     done
#     ffmpeg -framerate 1 -i "$_render_dir"/output_%03d.png -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -c:v libx264 -preset slow -profile:v high -level:v 4.0 -pix_fmt yuv420p -crf 1 "$_render_dir"/video.mp4
#     echo "--Finished rendering pngs to video--"
# }
# sleep 1
# render_dir_epic_field_e1="../../epi_corrections_out_2019_07_02/render_fields/EPIC/e1"
# render epic_field_files_e1 epic_label_files_e1 render_dir_epic_field_e1
# sleep 2 # Sleep 1 second; this was necessary otherwise the next call of render() function did seem to get emtpy render dir argument...
# render_dir_topup_field_e2="../../epi_corrections_out_2019_07_02/render_fields/EPIC/e2"
# render epic_field_files_e2 epic_label_files_e2 render_dir_topup_field_e2
# Out:
# --Finished rendering volume 0 to .png--
# --Finished rendering volume 1 to .png--
# --Finished rendering volume 2 to .png--
# --Finished rendering volume 3 to .png--
# --Finished rendering volume 4 to .png--
# --Finished rendering volume 5 to .png--
# --Finished rendering volume 6 to .png--
# --Finished rendering volume 7 to .png--
# --Finished rendering volume 8 to .png--
# --Finished rendering volume 9 to .png--
# --Finished rendering volume 10 to .png--
# --Finished rendering volume 11 to .png--
# --Finished rendering volume 12 to .png--
# --Finished rendering volume 13 to .png--
# --Finished rendering volume 14 to .png--
# --Finished rendering volume 15 to .png--
# --Finished rendering volume 16 to .png--
# --Finished rendering volume 17 to .png--
# --Finished rendering volume 18 to .png--
# --Finished rendering volume 19 to .png--
# --Finished rendering volume 20 to .png--
# --Finished rendering volume 21 to .png--
# --Finished rendering volume 22 to .png--
# --Finished rendering volume 23 to .png--
# --Finished rendering volume 24 to .png--
# --Finished rendering volume 25 to .png--
# --Finished rendering volume 26 to .png--
# --Finished rendering volume 27 to .png--
# --Finished rendering volume 28 to .png--
# --Finished rendering volume 29 to .png--
# --Finished rendering volume 30 to .png--
# --Finished rendering volume 31 to .png--
# --Finished rendering volume 32 to .png--
# --Finished rendering volume 33 to .png--
# --Finished rendering volume 34 to .png--
# --Finished rendering volume 35 to .png--
# --Finished rendering volume 36 to .png--
# --Finished rendering volume 37 to .png--
# --Finished rendering volume 38 to .png--
# --Finished rendering volume 39 to .png--
# --Finished rendering volume 40 to .png--
# --Finished rendering volume 41 to .png--
# --Finished rendering volume 42 to .png--
# --Finished rendering volume 43 to .png--
# --Finished rendering volume 44 to .png--
# --Finished rendering pngs to video--
# --Finished rendering volume 0 to .png--
# --Finished rendering volume 1 to .png--
# --Finished rendering volume 2 to .png--
# --Finished rendering volume 3 to .png--
# --Finished rendering volume 4 to .png--
# --Finished rendering volume 5 to .png--
# --Finished rendering volume 6 to .png--
# --Finished rendering volume 7 to .png--
# --Finished rendering volume 8 to .png--
# --Finished rendering volume 9 to .png--
# --Finished rendering volume 10 to .png--
# --Finished rendering volume 11 to .png--
# --Finished rendering volume 12 to .png--
# --Finished rendering volume 13 to .png--
# --Finished rendering volume 14 to .png--
# --Finished rendering volume 15 to .png--
# --Finished rendering volume 16 to .png--
# --Finished rendering volume 17 to .png--
# --Finished rendering volume 18 to .png--
# --Finished rendering volume 19 to .png--
# --Finished rendering volume 20 to .png--
# --Finished rendering volume 21 to .png--
# --Finished rendering volume 22 to .png--
# --Finished rendering volume 23 to .png--
# --Finished rendering volume 24 to .png--
# --Finished rendering volume 25 to .png--
# --Finished rendering volume 26 to .png--
# --Finished rendering volume 27 to .png--
# --Finished rendering volume 28 to .png--
# --Finished rendering volume 29 to .png--
# --Finished rendering volume 30 to .png--
# --Finished rendering volume 31 to .png--
# --Finished rendering volume 32 to .png--
# --Finished rendering volume 33 to .png--
# --Finished rendering volume 34 to .png--
# --Finished rendering volume 35 to .png--
# --Finished rendering volume 36 to .png--
# --Finished rendering volume 37 to .png--
# --Finished rendering volume 38 to .png--
# --Finished rendering volume 39 to .png--
# --Finished rendering volume 40 to .png--
# --Finished rendering volume 41 to .png--
# --Finished rendering volume 42 to .png--
# --Finished rendering volume 43 to .png--
# --Finished rendering volume 44 to .png--
# --Finished rendering pngs to video--
# (wr_coregest_displacement_field_e1.nii:32484): Gtk-CRITICAL **: 20:22:25.547: gtk_window_resize: assertion 'width > 0' failed
# 20:22:25: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii
Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:645): Gtk-CRITICAL **: 20:24:55.968: gtk_window_resize: assertion 'width > 0' failed
# 20:24:56: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:665): Gtk-CRITICAL **: 20:25:01.640: gtk_window_resize: assertion 'width > 0' failed
# 20:25:01: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:694): Gtk-CRITICAL **: 20:25:07.195: gtk_window_resize: assertion 'width > 0' failed
# 20:25:07: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:720): Gtk-CRITICAL **: 20:25:12.849: gtk_window_resize: assertion 'width > 0' failed
# 20:25:12: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:743): Gtk-CRITICAL **: 20:25:18.407: gtk_window_resize: assertion 'width > 0' failed
# 20:25:18: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:768): Gtk-CRITICAL **: 20:25:23.835: gtk_window_resize: assertion 'width > 0' failed
# 20:25:23: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:791): Gtk-CRITICAL **: 20:25:29.413: gtk_window_resize: assertion 'width > 0' failed
# 20:25:29: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:812): Gtk-CRITICAL **: 20:25:35.050: gtk_window_resize: assertion 'width > 0' failed
# 20:25:35: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:836): Gtk-CRITICAL **: 20:25:40.668: gtk_window_resize: assertion 'width > 0' failed
# 20:25:40: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:857): Gtk-CRITICAL **: 20:25:46.199: gtk_window_resize: assertion 'width > 0' failed
# 20:25:46: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:879): Gtk-CRITICAL **: 20:25:51.884: gtk_window_resize: assertion 'width > 0' failed
# 20:25:52: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:900): Gtk-CRITICAL **: 20:25:57.455: gtk_window_resize: assertion 'width > 0' failed
# 20:25:57: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:921): Gtk-CRITICAL **: 20:26:03.243: gtk_window_resize: assertion 'width > 0' failed
# 20:26:03: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:951): Gtk-CRITICAL **: 20:26:08.683: gtk_window_resize: assertion 'width > 0' failed
# 20:26:08: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:975): Gtk-CRITICAL **: 20:26:14.252: gtk_window_resize: assertion 'width > 0' failed
# 20:26:14: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:1000): Gtk-CRITICAL **: 20:26:19.831: gtk_window_resize: assertion 'width > 0' failed
# 20:26:19: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:1021): Gtk-CRITICAL **: 20:26:25.561: gtk_window_resize: assertion 'width > 0' failed
# 20:26:25: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e1.nii:1047): Gtk-CRITICAL **: 20:26:31.182: gtk_window_resize: assertion 'width > 0' failed
# 20:26:31: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
# ffmpeg version 4.0.4-0ubuntu1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 8 (Ubuntu 8.2.0-7ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, image2, from '../../epi_corrections_out_2019_07_02/render_fields/EPIC/e1/output_%03d.png':
#   Duration: 00:00:45.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 800x600 [SAR 3937:3937 DAR 4:3], 1 fps, 1 tbr, 1 tbn, 1 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x564d225d4400] using SAR=1/1
# [libx264 @ 0x564d225d4400] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.1 Cache64
# [libx264 @ 0x564d225d4400] profile High, level 4.0
# [libx264 @ 0x564d225d4400] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=1 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../epi_corrections_out_2019_07_02/render_fields/EPIC/e1/video.mp4':
#   Metadata:
#     encoder         : Lavf58.12.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 800x600 [SAR 1:1 DAR 4:3], q=-1--1, 1 fps, 16384 tbn, 1 tbc
#     Metadata:
#       encoder         : Lavc58.18.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   45 fps= 12 q=-1.0 L10000000000000000000000000000000size=    3117kB time=00:00:42.00 bitrate= 607.9kbits/s speed=11.5x
# video:3115kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.044982%
# [libx264 @ 0x564d225d4400] frame I:1     Avg QP: 0.19  size: 90191
# [libx264 @ 0x564d225d4400] frame P:14    Avg QP: 0.51  size: 68976
# [libx264 @ 0x564d225d4400] frame B:30    Avg QP: 0.69  size: 71121
# [libx264 @ 0x564d225d4400] consecutive B-frames:  4.4% 17.8%  6.7% 71.1%
# [libx264 @ 0x564d225d4400] mb I  I16..4: 60.4%  0.0% 39.6%
# [libx264 @ 0x564d225d4400] mb P  I16..4:  4.1%  0.1% 18.4%  P16..4:  6.1%  2.7%  2.6%  0.0%  0.0%    skip:65.9%
# [libx264 @ 0x564d225d4400] mb B  I16..4:  1.2%  0.1% 16.8%  B16..8:  5.5%  2.3%  2.9%  direct: 3.4%  skip:67.9%  L0:63.1% L1:26.0% BI:10.9%
# [libx264 @ 0x564d225d4400] 8x8 transform intra:0.4% inter:6.1%
# [libx264 @ 0x564d225d4400] direct mvs  spatial:86.7% temporal:13.3%
# [libx264 @ 0x564d225d4400] coded y,uvDC,uvAC intra: 80.3% 80.5% 80.5% inter: 10.9% 13.1% 13.1%
# [libx264 @ 0x564d225d4400] i16 v,h,dc,p: 81% 15%  3%  1%
# [libx264 @ 0x564d225d4400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 47% 27% 12%  1%  2%  2%  2%  5%  2%
# [libx264 @ 0x564d225d4400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 47% 29%  8%  3%  3%  2%  2%  3%  2%
# [libx264 @ 0x564d225d4400] i8c dc,h,v,p: 34% 17% 32% 16%
# [libx264 @ 0x564d225d4400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x564d225d4400] ref P L0: 25.6%  8.3% 30.0% 23.6% 12.5%
# [libx264 @ 0x564d225d4400] ref B L0: 50.5% 25.9% 18.9%  4.6%
# [libx264 @ 0x564d225d4400] ref B L1: 89.4% 10.6%
# [libx264 @ 0x564d225d4400] kb/s:567.02
#
# (wr_coregest_displacement_field_e2.nii:1088): Gtk-CRITICAL **: 20:26:41.673: gtk_window_resize: assertion 'width > 0' failed
# 20:26:41: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:1116): Gtk-CRITICAL **: 20:26:47.244: gtk_window_resize: assertion 'width > 0' failed
# 20:26:47: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:1139): Gtk-CRITICAL **: 20:26:52.874: gtk_window_resize: assertion 'width > 0' failed
# 20:26:53: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:1164): Gtk-CRITICAL **: 20:26:58.440: gtk_window_resize: assertion 'width > 0' failed
# 20:26:58: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:1184): Gtk-CRITICAL **: 20:27:04.133: gtk_window_resize: assertion 'width > 0' failed
# 20:27:04: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:1216): Gtk-CRITICAL **: 20:27:09.976: gtk_window_resize: assertion 'width > 0' failed
# 20:27:10: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:1240): Gtk-CRITICAL **: 20:27:15.645: gtk_window_resize: assertion 'width > 0' failed
# 20:27:15: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:1265): Gtk-CRITICAL **: 20:27:21.602: gtk_window_resize: assertion 'width > 0' failed
# 20:27:21: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:1293): Gtk-CRITICAL **: 20:27:27.239: gtk_window_resize: assertion 'width > 0' failed
# 20:27:27: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:1314): Gtk-CRITICAL **: 20:27:32.806: gtk_window_resize: assertion 'width > 0' failed
# 20:27:32: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:1335): Gtk-CRITICAL **: 20:27:38.503: gtk_window_resize: assertion 'width > 0' failed
# 20:27:38: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:1361): Gtk-CRITICAL **: 20:27:43.724: gtk_window_resize: assertion 'width > 0' failed
# 20:27:43: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:1382): Gtk-CRITICAL **: 20:27:49.230: gtk_window_resize: assertion 'width > 0' failed
# 20:27:49: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:1405): Gtk-CRITICAL **: 20:27:54.636: gtk_window_resize: assertion 'width > 0' failed
# 20:27:54: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:
Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:2113): Gtk-CRITICAL **: 20:30:38.397: gtk_window_resize: assertion 'width > 0' failed
# 20:30:38: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:2134): Gtk-CRITICAL **: 20:30:43.952: gtk_window_resize: assertion 'width > 0' failed
# 20:30:44: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
#
# (wr_coregest_displacement_field_e2.nii:2157): Gtk-CRITICAL **: 20:30:49.380: gtk_window_resize: assertion 'width > 0' failed
# 20:30:49: Debug: Adding duplicate image handler for 'Windows bitmap file'
#  WARNING       numpymodule.py   30: <module>        - Unable to load numpy_formathandler accelerator from OpenGL_accelerate
# ffmpeg version 4.0.4-0ubuntu1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 8 (Ubuntu 8.2.0-7ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, image2, from '../../epi_corrections_out_2019_07_02/render_fields/EPIC/e2/output_%03d.png':
#   Duration: 00:00:45.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 800x600 [SAR 3937:3937 DAR 4:3], 1 fps, 1 tbr, 1 tbn, 1 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f722402440] using SAR=1/1
# [libx264 @ 0x55f722402440] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.1 Cache64
# [libx264 @ 0x55f722402440] profile High, level 4.0
# [libx264 @ 0x55f722402440] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=1 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../../epi_corrections_out_2019_07_02/render_fields/EPIC/e2/video.mp4':
#   Metadata:
#     encoder         : Lavf58.12.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 800x600 [SAR 1:1 DAR 4:3], q=-1--1, 1 fps, 16384 tbn, 1 tbc
#     Metadata:
#       encoder         : Lavc58.18.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   45 fps= 12 q=-1.0 Lsize=    3373kB time=00:00:42.00 bitrate= 657.9kbits/s speed=11.3x
# video:3372kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.041216%
# [libx264 @ 0x55f722402440] frame I:1     Avg QP: 0.36  size: 97685
# [libx264 @ 0x55f722402440] frame P:15    Avg QP: 0.52  size: 75527
# [libx264 @ 0x55f722402440] frame B:29    Avg QP: 0.69  size: 76597
# [libx264 @ 0x55f722402440] consecutive B-frames:  4.4% 26.7%  6.7% 62.2%
# [libx264 @ 0x55f722402440] mb I  I16..4: 60.7%  0.1% 39.2%
# [libx264 @ 0x55f722402440] mb P  I16..4:  3.8%  0.1% 16.9%  P16..4:  6.2%  3.5%  3.5%  0.0%  0.0%    skip:66.1%
# [libx264 @ 0x55f722402440] mb B  I16..4:  0.9%  0.1% 17.0%  B16..8:  5.7%  2.3%  3.5%  direct: 3.2%  skip:67.3%  L0:57.8% L1:30.3% BI:11.9%
# [libx264 @ 0x55f722402440] 8x8 transform intra:0.4% inter:3.9%
# [libx264 @ 0x55f722402440] direct mvs  spatial:89.7% temporal:10.3%
# [libx264 @ 0x55f722402440] coded y,uvDC,uvAC intra: 81.5% 81.6% 81.6% inter: 11.7% 13.9% 13.9%
# [libx264 @ 0x55f722402440] i16 v,h,dc,p: 82% 14%  3%  1%
# [libx264 @ 0x55f722402440] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 42% 18% 21%  2%  3%  5%  2%  4%  3%
# [libx264 @ 0x55f722402440] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 48% 28%  8%  3%  4%  3%  2%  3%  2%
# [libx264 @ 0x55f722402440] i8c dc,h,v,p: 35% 17% 34% 14%
# [libx264 @ 0x55f722402440] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55f722402440] ref P L0: 20.1%  7.8% 28.7% 19.7% 23.7%
# [libx264 @ 0x55f722402440] ref B L0: 43.8% 32.5% 18.8%  4.9%
# [libx264 @ 0x55f722402440] ref B L1: 80.0% 20.0%
# [libx264 @ 0x55f722402440] kb/s:613.67
