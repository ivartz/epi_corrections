# %% [markdown]
# This notebook MNI normalizes native flair tumor segmets from the Deep Learning-based segmentation part of
# the pipeline described in
# Juan-Albarracín, J., Fuster-Garcia, E. et. al.,"ONCOhabitats: A system for glioblastoma heterogeneity assessment through MRI".
#
# Link: https://www.sciencedirect.com/science/article/pii/S1386505618308001

# %%
output_directory_suffix = "2019_07_02"
corrections_base_directory = "../epi_corrections_out_" + output_directory_suffix
"""
The following folder is assumed to exist within corrections_base_directory:
"""
ONCOHabitats_results_folder = "ONCOHabitats_tumor_segments_from_flair_native"

# %%
from os import getcwd
from os.path import abspath
epi_corrections_root_directory = abspath(getcwd() + "/..") # Go one directory up from current working directory
epi_corrections_root_directory
# Out:
# '/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections'

# %% [markdown]
# 1. Convert the relevant files from .nii.gz to .nii and reslice to DSC MNI space

# %%
# %%bash -s "$epi_corrections_root_directory" "$corrections_base_directory" "$output_directory_suffix" "$ONCOHabitats_results_folder"
# epi_corrections_root_directory=$1
# corrections_base_directory=../$2
# output_directory_suffix=$3
# ONCOHabitats_results_folder=$4
#
# spm_path=/media/loek/HDD3TB1/apps/spm12 # This needs to be changed
# cd $epi_corrections_root_directory
# pipeline_report_file=$2/pipeline_report_spm_$output_directory_suffix.txt
# run_command='matlab
#                 -nodisplay
#                 -nosplash
#                 -nodesktop
#                 -r "cd('"'spm_pipeline'"');
#                     addpath('"'$spm_path'"');
#                     myCluster = parcluster;
#                     myCluster.NumWorkers = 6;
#                     saveProfile(myCluster);
#                     parpool(6);
#                     normalize_oncohabitats_native_flair_tumor_segments_to_mni('"'$corrections_base_directory'"', '"'$ONCOHabitats_results_folder'"');
#                     exit;"
#                 2>&1 | tee -a $pipeline_report_file'
# eval $run_command
# Out:
#                             < M A T L A B (R) >
#                   Copyright 1984-2018 The MathWorks, Inc.
#                    R2018b (9.5.0.944444) 64-bit (glnxa64)
#                               August 28, 2018
#
#
# To get started, type doc.
# For product information, visit www.mathworks.com.
#
# Starting parallel pool (parpool) using the 'local' profile ...
# connected to 6 workers.
# Initialising batch system... done.
# Initialising batch system... done.
# Initialising batch system... done.
# Initialising batch system... done.
# Initialising batch system... done.
# Initialising batch system... done.
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:03 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:03 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:03 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:03 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:03 - Running job #1
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:03 - Running job #1
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:03 - Running job #1
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:03 - Running job #1
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:03 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:03 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:03 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:03 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:05 - Running job #1
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:05 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:03 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:03 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:03 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:05 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:03 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:03 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:03 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:05 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:03 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:04 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:04 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:05 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:06 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:06 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:06 - Done
#
# 03-Dec-2019 18:28:03 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:03 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:03 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:06 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:05 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:06 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:06 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:07 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:06 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:06 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:06 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:07 - Running job #1
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:08 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:05 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:06 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:06 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:08 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:08 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:08 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:08 - Done
#
# 03-Dec-2019 18:28:06 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:06 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:06 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:08 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:05 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:06 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:06 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:07 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:07 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:08 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:08 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:09 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:07 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:08 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:08 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:09 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:08 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:08 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:08 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:10 - Running job #1
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:09 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:08 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:08 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:08 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:09 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:07 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:08 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:08 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:09 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:09 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:10 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:10 - Done
#
# 03-Dec-2019 18:28:09 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:10 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:10 - Done
#
# 03-Dec-2019 18:28:09 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:09 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:09 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:11 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:11 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:11 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:11 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:11 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:09 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:10 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:10 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:11 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:11 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:12 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:12 - Done
#
# 03-Dec-2019 18:28:10 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:10 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:10 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:12 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:09 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:10 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:10 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:12 - Running job #1
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:12 - Running job #1
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:13 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:11 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:12 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:12 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:13 - Running job #1
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:14 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:12 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:12 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:12 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:14 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:13 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:14 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:14 - Done
#
# 03-Dec-2019 18:28:12 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:12 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:12 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:14 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:14 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:15 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:15 - Done
#
# 03-Dec-2019 18:28:12 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:12 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:12 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:14 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:13 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:14 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:14 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:16 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:16 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:16 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:16 - Done
#
# 03-Dec-2019 18:28:14 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:14 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:14 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:16 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:14 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:14 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:14 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:16 - Running job #1
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:16 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:16 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:17 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:17 - Done
#
# 03-Dec-2019 18:28:16 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:17 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:17 - Done
#
# 03-Dec-2019 18:28:16 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:17 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:17 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:17 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:17 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:17 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:17 - Done
#
# 03-Dec-2019 18:28:14 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:15 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:15 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:17 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:17 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:17 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:17 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:18 - Running job #1
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:18 - Running job #1
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:18 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:18 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:18 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:18 - Done
#
# 03-Dec-2019 18:28:18 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:18 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:18 - Done
#
# 03-Dec-2019 18:28:18 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:18 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:18 - Done
#
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:19 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:19 - Running 'Gunzip Files'
# 03-Dec-2019 18:28:19 - Done    'Gunzip Files'
# 03-Dec-2019 18:28:19 - Done
#
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:21 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:21 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:29 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:21 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:21 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:29 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:21 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:21 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:29 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:21 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:21 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:29 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:21 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:21 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:29 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:21 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:21 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:29 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:29 - Done
#
# Loop3:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1148859267/results/native/wSegmentation_Flair_space.nii
# Loop3:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1148859267/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:29 - Done
#
# Loop6:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1221966156/results/native/wSegmentation_Flair_space.nii
# Loop6:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1221966156/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:29 - Done
#
# Loop10:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1437382072/results/native/wSegmentation_Flair_space.nii
# Loop10:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1437382072/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:29 - Done
#
# Loop17:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1612896456/results/native/wSegmentation_Flair_space.nii
# Loop17:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1612896456/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:29 - Done
#
# Loop29:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/182153134/results/native/wSegmentation_Flair_space.nii
# Loop29:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/182153134/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:29 - Done
#
# Loop49:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/3248093403/results/native/wSegmentation_Flair_space.nii
# Loop49:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/3248093403/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:31 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:31 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:33 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:31 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:31 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:35 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:33 - Done
#
# Loop28:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1778076422/results/native/wSegmentation_Flair_space.nii
# Loop28:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1778076422/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:34 - Running job #1
# ------------------------------------------------------------------------
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:31 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:31 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:36 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:31 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:31 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:35 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:31 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:31 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:36 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:31 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:31 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:36 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:35 - Done
#
# Loop5:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1221966156/results/native/wSegmentation_Flair_space.nii
# Loop5:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1221966156/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:35 - Done
#
# Loop16:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1492494416/results/native/wSegmentation_Flair_space.nii
# Loop16:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1492494416/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:34 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:36 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:36 - Done
#
# Loop2:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1099269047/results/native/wSegmentation_Flair_space.nii
# Loop2:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1099269047/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:36 - Done
#
# Loop9:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1437382072/results/native/wSegmentation_Flair_space.nii
# Loop9:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1437382072/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:37 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:37 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:38 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:36 - Done
#
# Loop27:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1778076422/results/native/wSegmentation_Flair_space.nii
# Loop27:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1778076422/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:36 - Done
#
# Loop48:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/274299819/results/native/wSegmentation_Flair_space.nii
# Loop48:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/274299819/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:37 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:37 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:38 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:38 - Done
#
# Loop4:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1148859267/results/native/wSegmentation_Flair_space.nii
# Loop4:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1148859267/results/mni/Segmentation.nii
# 03-Dec-2019 18:28:38 - Done
#
# Loop15:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1492494416/results/native/wSegmentation_Flair_space.nii
# Loop15:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1492494416/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:39 - Running job #1
# ------------------------------------------------------------------------
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:38 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:38 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:42 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:38 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:38 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:43 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:43 - Done
#
# Loop1:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1099269047/results/native/wSegmentation_Flair_space.nii
# Loop1:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1099269047/results/mni/Segmentation.nii
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:38 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:38 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:43 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:38 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:38 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:43 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:39 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:44 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:42 - Done
#
# Loop8:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1269262582/results/native/wSegmentation_Flair_space.nii
# Loop8:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1269262582/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:39 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:39 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:44 - Done    'Normalise: Write'
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:44 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:44 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:45 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:45 - Done
#
# Loop7:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1269262582/results/native/wSegmentation_Flair_space.nii
# Loop7:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1269262582/results/mni/Segmentation.nii
# 03-Dec-2019 18:28:44 - Done
#
# Loop14:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1489362944/results/native/wSegmentation_Flair_space.nii
# Loop14:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1489362944/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:43 - Done
#
# Loop26:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1767888627/results/native/wSegmentation_Flair_space.nii
# Loop26:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1767888627/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:43 - Done
#
# Loop47:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/274299819/results/native/wSegmentation_Flair_space.nii
# Loop47:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/274299819/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:44 - Done
#
# Loop95:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1221966156/results/native/wSegmentation_Flair_space.nii
# Loop95:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1221966156/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:45 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:45 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:47 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:47 - Done
#
# Loop72:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/682599102/results/native/wSegmentation_Flair_space.nii
# Loop72:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/682599102/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:45 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:45 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:49 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:45 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:45 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:49 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:45 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:45 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:48 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:46 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:46 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:50 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:48 - Done
#
# Loop46:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/207474919/results/native/wSegmentation_Flair_space.nii
# Loop46:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/207474919/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:45 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:45 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:51 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:49 - Done
#
# Loop13:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1489362944/results/native/wSegmentation_Flair_space.nii
# Loop13:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1489362944/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:49 - Done
#
# Loop25:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1767888627/results/native/wSegmentation_Flair_space.nii
# Loop25:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1767888627/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:49 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:49 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:52 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:50 - Done
#
# Loop118:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1778076422/results/native/wSegmentation_Flair_space.nii
# Loop118:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1778076422/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:50 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:50 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:52 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:52 - Done
#
# Loop71:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/682599102/results/native/wSegmentation_Flair_space.nii
# Loop71:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/682599102/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:51 - Done
#
# Loop94:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1148859267/results/native/wSegmentation_Flair_space.nii
# Loop94:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1148859267/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:51 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:51 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:54 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:50 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:50 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:54 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:52 - Done
#
# Loop45:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/207474919/results/native/wSegmentation_Flair_space.nii
# Loop45:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/207474919/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:51 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:51 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:54 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:54 - Done
#
# Loop12:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1439042234/results/native/wSegmentation_Flair_space.nii
# Loop12:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1439042234/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:54 - Done
#
# Loop24:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1739512447/results/native/wSegmentation_Flair_space.nii
# Loop24:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1739512447/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:54 - Done
#
# Loop117:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1778076422/results/native/wSegmentation_Flair_space.nii
# Loop117:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1778076422/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:54 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:54 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:57 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:53 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:54 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:58 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:57 - Done
#
# Loop44:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/2073077295/results/native/wSegmentation_Flair_space.nii
# Loop44:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/2073077295/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:58 - Done
#
# Loop70:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/681108541/results/native/wSegmentation_Flair_space.nii
# Loop70:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/681108541/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:59 - Running job #1
# ------------------------------------------------------------------------
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:53 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:53 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:59 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:55 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:55 - Running 'Normalise: Write'
# 03-Dec-2019 18:29:00 - Done    'Normalise: Write'
# 03-Dec-2019 18:29:00 - Done
#
# Loop11:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1439042234/results/native/wSegmentation_Flair_space.nii
# Loop11:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1439042234/results/mni/Segmentation.nii
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:55 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:55 - Running 'Normalise: Write'
# 03-Dec-2019 18:28:59 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:59 - Done
#
# Loop93:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1148859267/results/native/wSegmentation_Flair_space.nii
# Loop93:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1148859267/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:55 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:28:55 - Running 'Normalise: Write'
# 03-Dec-2019 18:29:00 - Done    'Normalise: Write'
# 03-Dec-2019 18:28:59 - Done
#
# Loop23:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1739512447/results/native/wSegmentation_Flair_space.nii
# Loop23:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1739512447/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:28:59 - Running 'Normalise: Write'
# ...
# 03-Dec-2019 18:31:17 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:17 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:18 - Done    'Normalise: Write'
# 03-Dec-2019 18:31:18 - Done
#
# Loop263:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/874046738/results/native/wSegmentation_Flair_space.nii
# Loop263:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/874046738/results/mni/Segmentation.nii
# 03-Dec-2019 18:31:17 - Done
#
# Loop249:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/681108541/results/native/wSegmentation_Flair_space.nii
# Loop249:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/681108541/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:31:18 - Done
#
# Loop183:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1148859267/results/native/wSegmentation_Flair_space.nii
# Loop183:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1148859267/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:18 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:18 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:19 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:19 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:19 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:20 - Done    'Normalise: Write'
# 03-Dec-2019 18:31:20 - Done
#
# Loop248:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/639060172/results/native/wSegmentation_Flair_space.nii
# Loop248:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/639060172/results/mni/Segmentation.nii
# 03-Dec-2019 18:31:18 - Done
#
# Loop262:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/852088633/results/native/wSegmentation_Flair_space.nii
# Loop262:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/852088633/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:19 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:19 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:21 - Done    'Normalise: Write'
# 03-Dec-2019 18:31:21 - Done
#
# Loop182:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1099269047/results/native/wSegmentation_Flair_space.nii
# Loop182:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/1099269047/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:19 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:19 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:21 - Done    'Normalise: Write'
# 03-Dec-2019 18:31:19 - Done
#
# Loop241:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/598418618/results/native/wSegmentation_Flair_space.nii
# Loop241:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/598418618/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:20 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:20 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:21 - Done    'Normalise: Write'
# 03-Dec-2019 18:31:21 - Done
#
# Loop261:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/852088633/results/native/wSegmentation_Flair_space.nii
# Loop261:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/852088633/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:20 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:20 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:21 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:20 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:20 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:21 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:22 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:22 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:23 - Done    'Normalise: Write'
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:31:21 - Done
#
# Loop270:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/969010965/results/native/wSegmentation_Flair_space.nii
# Loop270:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/969010965/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:31:21 - Done
#
# Loop268:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/930987463/results/native/wSegmentation_Flair_space.nii
# Loop268:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/930987463/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:31:21 - Done
#
# Loop240:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/585318379/results/native/wSegmentation_Flair_space.nii
# Loop240:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/585318379/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:31:23 - Done
#
# Loop266:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/878292297/results/native/wSegmentation_Flair_space.nii
# Loop266:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/878292297/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:22 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:22 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:24 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:22 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:22 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:24 - Done    'Normalise: Write'
# 03-Dec-2019 18:31:24 - Done
#
# Loop267:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/930987463/results/native/wSegmentation_Flair_space.nii
# Loop267:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/930987463/results/mni/Segmentation.nii
# 03-Dec-2019 18:31:24 - Done
#
# Loop258:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/792273679/results/native/wSegmentation_Flair_space.nii
# Loop258:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/792273679/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:23 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:23 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:25 - Done    'Normalise: Write'
# 03-Dec-2019 18:31:25 - Done
#
# Loop269:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/969010965/results/native/wSegmentation_Flair_space.nii
# Loop269:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/969010965/results/mni/Segmentation.nii
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:24 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:24 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:25 - Done    'Normalise: Write'
# 03-Dec-2019 18:31:25 - Done
#
# Loop265:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/878292297/results/native/wSegmentation_Flair_space.nii
# Loop265:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/878292297/results/mni/Segmentation.nii
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:23 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:23 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:25 - Done    'Normalise: Write'
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:25 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:25 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:26 - Done    'Normalise: Write'
# 03-Dec-2019 18:31:25 - Done
#
# Loop239:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/585318379/results/native/wSegmentation_Flair_space.nii
# Loop239:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/585318379/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# 03-Dec-2019 18:31:26 - Done
#
# Loop257:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/792273679/results/native/wSegmentation_Flair_space.nii
# Loop257:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/792273679/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:27 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:27 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:28 - Done    'Normalise: Write'
# 03-Dec-2019 18:31:28 - Done
#
# Loop256:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/758482469/results/native/wSegmentation_Flair_space.nii
# Loop256:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/758482469/results/mni/Segmentation.nii
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:26 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:26 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:27 - Done    'Normalise: Write'
# 03-Dec-2019 18:31:27 - Done
#
# Loop238:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/577314815/results/native/wSegmentation_Flair_space.nii
# Loop238:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/577314815/results/mni/Segmentation.nii
# Item 'Deformation Field', field 'val': Number of matching files (0) less than required (1).
# Item 'Images to Write', field 'val': Number of matching files (0) less than required (1).
#
#
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:28 - Running job #1
# ------------------------------------------------------------------------
# 03-Dec-2019 18:31:28 - Running 'Normalise: Write'
# 03-Dec-2019 18:31:29 - Done    'Normalise: Write'
# 03-Dec-2019 18:31:29 - Done
#
# Loop237:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/577314815/results/native/wSegmentation_Flair_space.nii
# Loop237:/media/loek/HDD3TB1/data/IVS_EPI_BASELINE/epi_corrections_out_2019_07_02/ONCOHabitats_tumor_segments_from_flair_native/577314815/results/mni/Segmentation.nii
